# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# One-hot encode the labels
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(train_images)

# Build the CNN model
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(datagen.flow(train_images, train_labels, batch_size=64),
                    epochs=20,
                    validation_data=(test_images, test_labels))

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy: {test_acc}')

# Get predictions on the test set
predictions = model.predict(test_images)

# Print some sample predictions
for i in range(5):
    print(f"Sample {i+1} - True Label: {tf.argmax(test_labels[i])}, Predicted Label: {tf.argmax(predictions[i])}")

# Save the model in native Keras format
model.save('image_classification_model.keras')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step
# Epoch 1/20
# 782/782 [==============================] - 101s 128ms/step - loss: 1.6216 - accuracy: 0.4031 - val_loss: 1.4462 - val_accuracy: 0.4929
# Epoch 2/20
# 782/782 [==============================] - 100s 127ms/step - loss: 1.3022 - accuracy: 0.5348 - val_loss: 1.2357 - val_accuracy: 0.5648
# Epoch 3/20
# 782/782 [==============================] - 100s 127ms/step - loss: 1.1689 - accuracy: 0.5854 - val_loss: 1.0878 - val_accuracy: 0.6174
# Epoch 4/20
# 782/782 [==============================] - 98s 126ms/step - loss: 1.0752 - accuracy: 0.6187 - val_loss: 1.0178 - val_accuracy: 0.6481
# Epoch 5/20
# 782/782 [==============================] - 101s 129ms/step - loss: 1.0166 - accuracy: 0.6413 - val_loss: 0.9242 - val_accuracy: 0.6835
# Epoch 6/20
# 782/782 [==============================] - 100s 128ms/step - loss: 0.9719 - accuracy: 0.6580 - val_loss: 0.8658 - val_accuracy: 0.6955
# Epoch 7/20
# 782/782 [==============================] - 99s 127ms/step - loss: 0.9235 - accuracy: 0.6740 - val_loss: 0.9180 - val_accuracy: 0.6782
# Epoch 8/20
# 782/782 [==============================] - 99s 127ms/step - loss: 0.8839 - accuracy: 0.6897 - val_loss: 0.8745 - val_accuracy: 0.7018
# Epoch 9/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.8461 - accuracy: 0.7020 - val_loss: 0.8384 - val_accuracy: 0.7115
# Epoch 10/20
# 782/782 [==============================] - 99s 127ms/step - loss: 0.8281 - accuracy: 0.7085 - val_loss: 0.7492 - val_accuracy: 0.7377
# Epoch 11/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.8012 - accuracy: 0.7193 - val_loss: 0.7430 - val_accuracy: 0.7441
# Epoch 12/20
# 782/782 [==============================] - 100s 128ms/step - loss: 0.7796 - accuracy: 0.7270 - val_loss: 0.7407 - val_accuracy: 0.7423
# Epoch 13/20
# 782/782 [==============================] - 102s 131ms/step - loss: 0.7694 - accuracy: 0.7302 - val_loss: 0.7383 - val_accuracy: 0.7458
# Epoch 14/20
# 782/782 [==============================] - 101s 129ms/step - loss: 0.7505 - accuracy: 0.7381 - val_loss: 0.7901 - val_accuracy: 0.7379
# Epoch 15/20
# 782/782 [==============================] - 96s 123ms/step - loss: 0.7303 - accuracy: 0.7449 - val_loss: 0.7256 - val_accuracy: 0.7514
# Epoch 16/20
# 782/782 [==============================] - 101s 129ms/step - loss: 0.7170 - accuracy: 0.7474 - val_loss: 0.8560 - val_accuracy: 0.7149
# Epoch 17/20
# 782/782 [==============================] - 98s 125ms/step - loss: 0.7028 - accuracy: 0.7545 - val_loss: 0.6863 - val_accuracy: 0.7635
# Epoch 18/20
# 782/782 [==============================] - 97s 124ms/step - loss: 0.6901 - accuracy: 0.7593 - val_loss: 0.7912 - val_accuracy: 0.7377
# Epoch 19/20
# 782/782 [==============================] - 96s 123ms/step - loss: 0.6752 - accuracy: 0.7614 - val_loss: 0.7188 - val_accuracy: 0.7614
# Epoch 20/20
# 782/782 [==============================] - 97s 124ms/step - loss: 0.6687 - accuracy: 0.7649 - val_loss: 0.7477 - val_accuracy: 0.7520
# 313/313 [==============================] - 5s 16ms/step - loss: 0.7477 - accuracy: 0.7520
# Test Accuracy: 0.7519999742507935
# 313/313 [==============================] - 6s 17ms/step
# Sample 1 - True Label: 3, Predicted Label: 3
# Sample 2 - True Label: 8, Predicted Label: 8
# Sample 3 - True Label: 8, Predicted Label: 8
# Sample 4 - True Label: 0, Predicted Label: 0
# Sample 5 - True Label: 6, Predicted Label: 6
